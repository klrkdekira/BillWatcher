# %%
from pathlib import Path

from docling.backend.docling_parse_backend import DoclingParseDocumentBackend
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import (
    EasyOcrOptions,
    OcrMacOptions,
    PdfPipelineOptions,
    RapidOcrOptions,
    TesseractCliOcrOptions,
    TesseractOcrOptions,
)
from docling.document_converter import DocumentConverter, PdfFormatOption

# %%
def main():
    input_doc = Path("../scraper_data/en/live/2024/2024_0/bill.pdf")

    pipeline_options = PdfPipelineOptions(
        ocr_options=TesseractOcrOptions(force_full_page_ocr=True),
    )
    pipeline_options.do_ocr = True
    pipeline_options.do_table_structure = True
    pipeline_options.table_structure_options.do_cell_matching = True

    # Any of the OCR options can be used:EasyOcrOptions, TesseractOcrOptions, TesseractCliOcrOptions, OcrMacOptions(Mac only), RapidOcrOptions
    # ocr_options = EasyOcrOptions(force_full_page_ocr=True)
    # ocr_options = TesseractOcrOptions(force_full_page_ocr=True)
    # ocr_options = OcrMacOptions(force_full_page_ocr=True)
    # ocr_options = RapidOcrOptions(force_full_page_ocr=True)
    ocr_options = TesseractCliOcrOptions(force_full_page_ocr=True)
    pipeline_options.ocr_options = ocr_options

    converter = DocumentConverter(
        format_options={
            InputFormat.PDF: PdfFormatOption(
                pipeline_options=pipeline_options,
            )
        }
    )

    doc = converter.convert(input_doc).document
    md = doc.export_to_markdown()
    print(md)

# %%
main()
# Out:
# Could not load the custom kernel for multi-scale deformable attention: CUDA_HOME environment variable is not set. Please set it to your CUDA install root.
# Could not load the custom kernel for multi-scale deformable attention: /home/cheeleong/.cache/torch_extensions/py312_cu124/MultiScaleDeformableAttention/MultiScaleDeformableAttention.so: cannot open shared object file: No such file or directory
# Could not load the custom kernel for multi-scale deformable attention: /home/cheeleong/.cache/torch_extensions/py312_cu124/MultiScaleDeformableAttention/MultiScaleDeformableAttention.so: cannot open shared object file: No such file or directory
# Could not load the custom kernel for multi-scale deformable attention: /home/cheeleong/.cache/torch_extensions/py312_cu124/MultiScaleDeformableAttention/MultiScaleDeformableAttention.so: cannot open shared object file: No such file or directory
# Could not load the custom kernel for multi-scale deformable attention: /home/cheeleong/.cache/torch_extensions/py312_cu124/MultiScaleDeformableAttention/MultiScaleDeformableAttention.so: cannot open shared object file: No such file or directory
# Could not load the custom kernel for multi-scale deformable attention: /home/cheeleong/.cache/torch_extensions/py312_cu124/MultiScaleDeformableAttention/MultiScaleDeformableAttention.so: cannot open shared object file: No such file or directory
# Encountered an error during conversion of document ba8d79e07907f1e63d6705e212cad779bbd7631fd969dc9dc4c468a907bc5200:
# Traceback (most recent call last):
#
#   File "/data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py", line 163, in _build_document
#     for p in pipeline_pages:  # Must exhaust!
#              ^^^^^^^^^^^^^^
#
#   File "/data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py", line 127, in _apply_on_pages
#     yield from page_batch
#
#   File "/data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/models/page_assemble_model.py", line 60, in __call__
#     for page in page_batch:
#                 ^^^^^^^^^^
#
#   File "/data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/models/table_structure_model.py", line 178, in __call__
#     for page in page_batch:
#                 ^^^^^^^^^^
#
#   File "/data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/models/layout_model.py", line 146, in __call__
#     for page in page_batch:
#                 ^^^^^^^^^^
#
#   File "/data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/models/tesseract_ocr_cli_model.py", line 209, in __call__
#     df = self._run_tesseract(fname)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/models/tesseract_ocr_cli_model.py", line 117, in _run_tesseract
#     df_filtered = df[df["text"].notnull() & (df["text"].str.strip() != "")]
#                                              ^^^^^^^^^^^^^^
#
#   File "/data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/pandas/core/generic.py", line 6299, in __getattr__
#     return object.__getattribute__(self, name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/pandas/core/accessor.py", line 224, in __get__
#     accessor_obj = self._accessor(obj)
#                    ^^^^^^^^^^^^^^^^^^^
#
#   File "/data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/pandas/core/strings/accessor.py", line 191, in __init__
#     self._inferred_dtype = self._validate(data)
#                            ^^^^^^^^^^^^^^^^^^^^
#
#   File "/data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/pandas/core/strings/accessor.py", line 245, in _validate
#     raise AttributeError("Can only use .str accessor with string values!")
#
# AttributeError: Can only use .str accessor with string values!. Did you mean: 'std'?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 main()
#
# Cell In[4], line 27, in main()
#      17 pipeline_options.ocr_options = ocr_options
#      19 converter = DocumentConverter(
#      20     format_options={
#      21         InputFormat.PDF: PdfFormatOption(
#    (...)
#      24     }
#      25 )
# ---> 27 doc = converter.convert(input_doc).document
#      28 md = doc.export_to_markdown()
#      29 print(md)
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/pydantic/_internal/_validate_call.py:38, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      36 @functools.wraps(wrapped)
#      37 def wrapper_function(*args, **kwargs):
# ---> 38     return wrapper(*args, **kwargs)
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/pydantic/_internal/_validate_call.py:111, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#     110 def __call__(self, *args: Any, **kwargs: Any) -> Any:
# --> 111     res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#     112     if self.__return_pydantic_validator__:
#     113         return self.__return_pydantic_validator__(res)
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/document_converter.py:212, in DocumentConverter.convert(self, source, headers, raises_on_error, max_num_pages, max_file_size, page_range)
#     194 @validate_call(config=ConfigDict(strict=True))
#     195 def convert(
#     196     self,
#    (...)
#     202     page_range: PageRange = DEFAULT_PAGE_RANGE,
#     203 ) -> ConversionResult:
#     204     all_res = self.convert_all(
#     205         source=[source],
#     206         raises_on_error=raises_on_error,
#    (...)
#     210         page_range=page_range,
#     211     )
# --> 212     return next(all_res)
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/document_converter.py:235, in DocumentConverter.convert_all(self, source, headers, raises_on_error, max_num_pages, max_file_size, page_range)
#     232 conv_res_iter = self._convert(conv_input, raises_on_error=raises_on_error)
#     234 had_result = False
# --> 235 for conv_res in conv_res_iter:
#     236     had_result = True
#     237     if raises_on_error and conv_res.status not in {
#     238         ConversionStatus.SUCCESS,
#     239         ConversionStatus.PARTIAL_SUCCESS,
#     240     }:
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/document_converter.py:270, in DocumentConverter._convert(self, conv_input, raises_on_error)
#     261 _log.info(f"Going to convert document batch...")
#     263 # parallel processing only within input_batch
#     264 # with ThreadPoolExecutor(
#     265 #    max_workers=settings.perf.doc_batch_concurrency
#     266 # ) as pool:
#     267 #   yield from pool.map(self.process_document, input_batch)
#     268 # Note: PDF backends are not thread-safe, thread pool usage was disabled.
# --> 270 for item in map(
#     271     partial(self._process_document, raises_on_error=raises_on_error),
#     272     input_batch,
#     273 ):
#     274     elapsed = time.monotonic() - start_time
#     275     start_time = time.monotonic()
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/document_converter.py:311, in DocumentConverter._process_document(self, in_doc, raises_on_error)
#     307 valid = (
#     308     self.allowed_formats is not None and in_doc.format in self.allowed_formats
#     309 )
#     310 if valid:
# --> 311     conv_res = self._execute_pipeline(in_doc, raises_on_error=raises_on_error)
#     312 else:
#     313     error_message = f"File format not allowed: {in_doc.file}"
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/document_converter.py:334, in DocumentConverter._execute_pipeline(self, in_doc, raises_on_error)
#     332 pipeline = self._get_pipeline(in_doc.format)
#     333 if pipeline is not None:
# --> 334     conv_res = pipeline.execute(in_doc, raises_on_error=raises_on_error)
#     335 else:
#     336     if raises_on_error:
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py:53, in BasePipeline.execute(self, in_doc, raises_on_error)
#      51     conv_res.status = ConversionStatus.FAILURE
#      52     if raises_on_error:
# ---> 53         raise e
#      54 finally:
#      55     self._unload(conv_res)
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py:45, in BasePipeline.execute(self, in_doc, raises_on_error)
#      39 try:
#      40     with TimeRecorder(
#      41         conv_res, "pipeline_total", scope=ProfilingScope.DOCUMENT
#      42     ):
#      43         # These steps are building and assembling the structure of the
#      44         # output DoclingDocument.
# ---> 45         conv_res = self._build_document(conv_res)
#      46         conv_res = self._assemble_document(conv_res)
#      47         # From this stage, all operations should rely only on conv_res.output
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py:198, in PaginatedPipeline._build_document(self, conv_res)
#     191         trace = "\n".join(
#     192             traceback.format_exception(type(e), e, e.__traceback__)
#     193         )
#     194         _log.warning(
#     195             f"Encountered an error during conversion of document {conv_res.input.document_hash}:\n"
#     196             f"{trace}"
#     197         )
# --> 198         raise e
#     200 return conv_res
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py:163, in PaginatedPipeline._build_document(self, conv_res)
#     160 # 2. Run pipeline stages
#     161 pipeline_pages = self._apply_on_pages(conv_res, init_pages)
# --> 163 for p in pipeline_pages:  # Must exhaust!
#     164
#     165     # Cleanup cached images
#     166     if not self.keep_images:
#     167         p._image_cache = {}
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py:127, in PaginatedPipeline._apply_on_pages(self, conv_res, page_batch)
#     124 for model in self.build_pipe:
#     125     page_batch = model(conv_res, page_batch)
# --> 127 yield from page_batch
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/models/page_assemble_model.py:60, in PageAssembleModel.__call__(self, conv_res, page_batch)
#      57 def __call__(
#      58     self, conv_res: ConversionResult, page_batch: Iterable[Page]
#      59 ) -> Iterable[Page]:
# ---> 60     for page in page_batch:
#      61         assert page._backend is not None
#      62         if not page._backend.is_valid():
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/models/table_structure_model.py:178, in TableStructureModel.__call__(self, conv_res, page_batch)
#     175     yield from page_batch
#     176     return
# --> 178 for page in page_batch:
#     179     assert page._backend is not None
#     180     if not page._backend.is_valid():
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/models/layout_model.py:146, in LayoutModel.__call__(self, conv_res, page_batch)
#     142 def __call__(
#     143     self, conv_res: ConversionResult, page_batch: Iterable[Page]
#     144 ) -> Iterable[Page]:
# --> 146     for page in page_batch:
#     147         assert page._backend is not None
#     148         if not page._backend.is_valid():
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/models/tesseract_ocr_cli_model.py:209, in TesseractOcrCliModel.__call__(self, conv_res, page_batch)
#     206         fname = image_file.name
#     207         high_res_image.save(image_file)
# --> 209     df = self._run_tesseract(fname)
#     210 finally:
#     211     if os.path.exists(fname):
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/docling/models/tesseract_ocr_cli_model.py:117, in TesseractOcrCliModel._run_tesseract(self, ifilename)
#     111 df = pd.read_csv(io.StringIO(decoded_data), quoting=csv.QUOTE_NONE, sep="\t")
#     113 # Display the dataframe (optional)
#     114 # _log.info("df: ", df.head())
#     115
#     116 # Filter rows that contain actual text (ignore header or empty rows)
# --> 117 df_filtered = df[df["text"].notnull() & (df["text"].str.strip() != "")]
#     119 return df_filtered
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/pandas/core/strings/accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File /data/BillWatcher-2.0/.venv/lib/python3.12/site-packages/pandas/core/strings/accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!
